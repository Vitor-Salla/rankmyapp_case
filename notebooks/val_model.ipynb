# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ### Lendo dados

# %%
df = pd.read_csv("../data/forecasts.csv", index_col=0)

# %% [markdown]
# ### Analisando alguns gráficos

# %%
appId = "com.app.36612"

plt.figure(figsize=(12, 5))
sns.lineplot(data=df[df["appId"]==appId], x='date', y='forecast',   label='Forecast')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dauReal', label='DAU Real')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dau_avg', label='DAU Média')
plt.xticks([0, 5, 10, 15, 20, 25, 30]);

# %%
appId = "com.app.27567"

plt.figure(figsize=(12, 5))
sns.lineplot(data=df[df["appId"]==appId], x='date', y='forecast',   label='Forecast')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dauReal', label='DAU Real')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dau_avg', label='DAU Média')

plt.xticks([0, 5, 10, 15, 20, 25, 30]);

# %%
appId = "com.app.17806"

plt.figure(figsize=(12, 5))
sns.lineplot(data=df[df["appId"]==appId], x='date', y='forecast',   label='Forecast')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dauReal', label='DAU Real')
sns.lineplot(data=df[df["appId"]==appId], x='date', y='dau_avg', label='DAU Média')

plt.xticks([0, 5, 10, 15, 20, 25, 30]);

# %% [markdown]
# ### Métricas

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error


df = df.dropna() # está com uma linha nula

# overall metrics
y_true = df['dauReal']
y_pred = df['forecast']

mae  = mean_absolute_error(y_true, y_pred)
mse  = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mape = (np.abs((y_true - y_pred) / y_true).mean()) * 100    # in percent

print(f"MAE: {mae:.0f}")
print(f"RMSE: {rmse:.0f}")
print(f"MAPE: {mape:.1f}%")
# Out:
# MAE: 55652
# RMSE: 203204
# MAPE: 18.3%

# %%
# comparando com um naive forecast (média por app)

y_true = df['dauReal']
y_pred = df['dau_avg']

mae  = mean_absolute_error(y_true, y_pred)
mse  = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mape = (np.abs((y_true - y_pred) / y_true).mean()) * 100    # in percent

print(f"MAE: {mae:.0f}")
print(f"RMSE: {rmse:.0f}")
print(f"MAPE: {mape:.1f}%")
# Out:
# MAE: 54168
# RMSE: 184475
# MAPE: 23.5%
